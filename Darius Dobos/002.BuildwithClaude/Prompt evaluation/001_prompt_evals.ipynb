# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""
    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
dataset = generate_dataset()

with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
def run_prompt(test_case):
    """Merges the prompt and test case input, then returs the result"""
    prompt =f"""
Please solve the following task:

{test_case['task']}
"""
    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
def grade_by_model(test_case, output):
    """Grades the output of the model by asking the model to grade it"""
    prompt = f"""

# %%
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    # TODO - Grading
    score = 10

    return {
        "output": output,
        "test_case": test_case,
        "score": score
    }

# %%
def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []
    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results =run_eval(dataset)

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# AWS S3 URI Parser\n\nHere's a Python function that parses AWS S3 bucket URIs:\n\n```python\ndef parse_s3_uri(uri):\n    \"\"\"\n    Parse an AWS S3 bucket URI and return bucket and key.\n    \n    Args:\n        uri (str): S3 URI in the format 's3://bucket-name/path/to/file'\n    \n    Returns:\n        dict: Dictionary with 'bucket' and 'key' keys\n    \n    Raises:\n        ValueError: If the URI format is invalid\n    \n    Example:\n        >>> parse_s3_uri('s3://my-bucket/path/to/file.txt')\n        {'bucket': 'my-bucket', 'key': 'path/to/file.txt'}\n    \"\"\"\n    if not isinstance(uri, str):\n        raise ValueError(\"URI must be a string\")\n    \n    if not uri.startswith('s3://'):\n        raise ValueError(\"URI must start with 's3://'\")\n    \n    # Remove 's3://' prefix\n    uri_without_prefix = uri[5:]\n    \n    # Split on first '/'\n    parts = uri_without_prefix.split('/', 1)\n    \n    if len(parts) < 1 or not parts[0]:\n        raise ValueError(\"URI must contain a bucket name\")\n    \n    bucket = parts[0]\n    key = parts[1] if len(parts) > 1 else ''\n    \n    if not key:\n        raise ValueError(\"URI must contain a key/path\")\n    \n    return {'bucket': bucket, 'key': key}\n```\n\n## Usage Examples\n\n```python\n# Basic usage\nresult = parse_s3_uri('s3://my-bucket/path/to/file.txt')\nprint(result)\n# Output: {'bucket': 'my-bucket', 'key': 'path/to/file.txt'}\n\n# With nested folders\nresult = parse_s3_uri('s3://data-bucket/2024/01/15/report.pdf')\nprint(result)\n# Output: {'bucket': 'data-bucket', 'key': '2024/01/15/report.pdf'}\n\n# Simple key\nresult = parse_s3_uri('s3://bucket/file.txt')\nprint(result)\n# Output: {'bucket': 'bucket', 'key': 'file.txt'}\n```\n\n## Error Handling\n\n```python\n# Test error cases\ntry:\n    parse_s3_uri('https://my-bucket/file.txt')  # Wrong protocol\nexcept ValueError as e:\n    print(f\"Error: {e}\")  # Error: URI must start with 's3://'\n\ntry:\n    parse_s3_uri('s3://')  # Missing bucket\nexcept ValueError as e:\n    print(f\"Error: {e}\")  # Error: URI must contain a bucket name\n\ntry:\n    parse_s3_uri('s3://bucket')  # Missing key\nexcept ValueError as e:\n    print(f\"Error: {e}\")  # Error: URI must contain a key/path\n```\n\n## Alternative Implementation (More Lenient)\n\nIf you want to allow URIs without a key:\n\n```python\ndef parse_s3_uri_lenient(uri):\n    \"\"\"More lenient version that allows URIs without a key.\"\"\"\n    if not isinstance(uri, str):\n        raise ValueError(\"URI must be a string\")\n    \n    if not uri.startswith('s3://'):\n        raise ValueError(\"URI must start with 's3://'\")\n    \n    uri_without_prefix = uri[5:]\n    parts = uri_without_prefix.split('/', 1)\n    \n    bucket = parts[0]\n    key = parts[1] if len(parts) > 1 else None\n    \n    if not bucket:\n        raise ValueError(\"URI must contain a bucket name\")\n    \n    return {'bucket': bucket, 'key': key}\n\n# This allows:\nprint(parse_s3_uri_lenient('s3://my-bucket'))\n# Output: {'bucket': 'my-bucket', 'key': None}\n```\n\n## Using urllib (Another Approach)\n\n```python",
#     "test_case": {
#       "task": "Write a Python function that parses an AWS S3 bucket URI (e.g., 's3://my-bucket/path/to/file.txt') and returns a dictionary with keys 'bucket' and 'key'."
#     },
#     "score": 10
#   },
#   {
#     "output": "# AWS IAM S3 Read-Only Policy\n\nHere's a JSON object that represents an IAM policy allowing read-only access to all objects in the S3 bucket:\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Sid\": \"S3ReadOnlyAccess\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:GetObjectVersion\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-data-bucket/*\"\n    },\n    {\n      \"Sid\": \"S3ListBucketAccess\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:ListBucket\",\n        \"s3:GetBucketVersioning\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-data-bucket\"\n    }\n  ]\n}\n```\n\n## Explanation:\n\n| Component | Purpose |\n|-----------|---------|\n| **Version** | Specifies the policy language version (standard for modern AWS) |\n| **Statement 1** | Allows reading objects from the bucket |\n| **s3:GetObject** | Allows downloading/reading objects |\n| **s3:GetObjectVersion** | Allows accessing previous versions of objects |\n| **Resource (/*)** | Applies to all objects within the bucket |\n| **Statement 2** | Allows listing bucket contents |\n| **s3:ListBucket** | Allows listing objects in the bucket |\n| **s3:GetBucketVersioning** | Allows checking versioning status |\n| **Resource (bucket)** | Applies to the bucket itself |\n\nThis policy provides **read-only access** without allowing any write, delete, or bucket configuration modifications.",
#     "test_case": {
#       "task": "Create a JSON object that represents an AWS IAM policy allowing read-only access to all objects in an S3 bucket named 'my-data-bucket'."
#     },
#     "score": 10
#   },
#   {
#     "output": "# AWS EC2 Instance ID Regular Expression\n\nHere's the regular expression that matches valid AWS EC2 instance IDs:\n\n```regex\n^i-[0-9a-f]{8}([0-9a-f]{9})?$\n```\n\n## Explanation\n\n| Component | Meaning |\n|-----------|---------|\n| `^` | Start of string |\n| `i-` | Literal \"i-\" prefix |\n| `[0-9a-f]{8}` | Exactly 8 hexadecimal characters (0-9, a-f) |\n| `([0-9a-f]{9})?` | Optionally followed by 9 more hex characters (making 17 total) |\n| `$` | End of string |\n\n## Valid Examples\n\n\u2705 **8 hex characters (shorter format):**\n```\ni-01234567\ni-abcdef01\ni-0a1b2c3d\n```\n\n\u2705 **17 hex characters (longer format):**\n```\ni-0123456789abcdef0\ni-1234567890abcdef0\ni-0a1b2c3d4e5f6g7h8\n```\n\n## Invalid Examples\n\n\u274c `i-123456` (too few characters)\n\u274c `i-0123456789abcdef` (9 hex chars - not 8 or 17)\n\u274c `i-ABCDEF01` (uppercase not allowed)\n\u274c `0-01234567` (missing 'i' prefix)\n\n## Usage Examples\n\n**JavaScript:**\n```javascript\nconst pattern = /^i-[0-9a-f]{8}([0-9a-f]{9})?$/;\nconsole.log(pattern.test('i-0123456789abcdef0')); // true\nconsole.log(pattern.test('i-01234567'));         // true\nconsole.log(pattern.test('i-123'));              // false\n```\n\n**Python:**\n```python\nimport re\npattern = r'^i-[0-9a-f]{8}([0-9a-f]{9})?$'\nprint(re.match(pattern, 'i-0123456789abcdef0'))  # Match object (true)\nprint(re.match(pattern, 'i-123'))                # None (false)\n```",
#     "test_case": {
#       "task": "Write a regular expression that matches valid AWS EC2 instance IDs (format: i-followed by 8 or 17 hexadecimal characters, e.g., i-0123456789abcdef0)."
#     },
#     "score": 10
#   }
# ]
