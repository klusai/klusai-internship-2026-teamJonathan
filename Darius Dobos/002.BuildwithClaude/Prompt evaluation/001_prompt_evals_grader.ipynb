# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""

    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 6.666666666666667

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# AWS CloudFormation Template Resource Parser\n\nHere's a Python solution to extract all resource logical IDs from a CloudFormation template:\n\n```python\nimport json\nimport yaml\nfrom typing import List, Dict, Any\n\ndef parse_cloudformation_template(template_content: str) -> List[str]:\n    \"\"\"\n    Parse AWS CloudFormation template and extract all resource logical IDs.\n    \n    Args:\n        template_content: CloudFormation template as string (JSON or YAML)\n    \n    Returns:\n        List of resource logical IDs\n    \"\"\"\n    \n    # Try to parse as JSON first, then YAML\n    try:\n        template = json.loads(template_content)\n    except json.JSONDecodeError:\n        try:\n            template = yaml.safe_load(template_content)\n        except yaml.YAMLError as e:\n            raise ValueError(f\"Failed to parse template: {e}\")\n    \n    # Extract resources section\n    if not isinstance(template, dict):\n        raise ValueError(\"Template must be a JSON or YAML object\")\n    \n    resources = template.get(\"Resources\", {})\n    \n    if not isinstance(resources, dict):\n        raise ValueError(\"Resources section must be an object/dictionary\")\n    \n    # Return all logical IDs (keys in Resources)\n    return list(resources.keys())\n\n\n# Example usage with JSON template\njson_template = \"\"\"\n{\n  \"AWSTemplateFormatVersion\": \"2010-09-09\",\n  \"Description\": \"Sample CloudFormation Template\",\n  \"Resources\": {\n    \"MyBucket\": {\n      \"Type\": \"AWS::S3::Bucket\",\n      \"Properties\": {\n        \"BucketName\": \"my-bucket\"\n      }\n    },\n    \"MyEC2Instance\": {\n      \"Type\": \"AWS::EC2::Instance\",\n      \"Properties\": {\n        \"ImageId\": \"ami-12345678\"\n      }\n    },\n    \"MySecurityGroup\": {\n      \"Type\": \"AWS::EC2::SecurityGroup\",\n      \"Properties\": {\n        \"GroupDescription\": \"My security group\"\n      }\n    }\n  }\n}\n\"\"\"\n\n# Example usage with YAML template\nyaml_template = \"\"\"\nAWSTemplateFormatVersion: '2010-09-09'\nDescription: Sample CloudFormation Template\nResources:\n  MyBucket:\n    Type: AWS::S3::Bucket\n    Properties:\n      BucketName: my-bucket\n  MyEC2Instance:\n    Type: AWS::EC2::Instance\n    Properties:\n      ImageId: ami-12345678\n  MySecurityGroup:\n    Type: AWS::EC2::SecurityGroup\n    Properties:\n      GroupDescription: My security group\n\"\"\"\n\nif __name__ == \"__main__\":\n    print(\"=\" * 50)\n    print(\"Parsing JSON Template:\")\n    print(\"=\" * 50)\n    json_resources = parse_cloudformation_template(json_template)\n    print(f\"Found {len(json_resources)} resources:\")\n    for resource_id in json_resources:\n        print(f\"  - {resource_id}\")\n    \n    print(\"\\n\" + \"=\" * 50)\n    print(\"Parsing YAML Template:\")\n    print(\"=\" * 50)\n    yaml_resources = parse_cloudformation_template(yaml_template)\n    print(f\"Found {len(yaml_resources)} resources:\")\n    for resource_id in yaml_resources:\n        print(f\"  - {resource_id}\")\n```\n\n**Output:**\n```\n==================================================\nParsing JSON Template:\n==================================================\nFound 3 resources:\n  - MyBucket\n  - MyEC2Instance\n  - MySecurityGroup\n\n==================================================\nParsing YAML Template:\n==================================================\nFound 3 resources:\n  - MyBucket\n  - MyEC2Instance\n  - MySecurityGroup\n```\n\n## Advanced Version with Resource Details\n\n```python\ndef parse_cloudformation_detailed(template_content: str) -> Dict[str, Dict[str, Any]]:\n    \"\"\"\n    Parse CloudFormation template and extract resource details.\n    \n    Returns:\n        Dictionary with logical IDs as keys and resource info as values\n    \"\"\"\n    try:\n        template",
#     "test_case": {
#       "task": "Parse an AWS CloudFormation template to extract all resource logical IDs",
#       "format": "python"
#     },
#     "score": 7,
#     "reasoning": "The core solution effectively accomplishes the primary task of extracting resource logical IDs from CloudFormation templates. The parsing logic is sound, supports both JSON and YAML formats, and includes appropriate validation. However, the solution is presented as incomplete with a truncated advanced version, suggesting it wasn't fully finished. The implementation lacks robustness for edge cases and doesn't validate logical ID format per AWS specifications. Despite these limitations, the working portion correctly solves the stated task with good code quality."
#   },
#   {
#     "output": "# S3 Read-Only Access Policy Document\n\nHere's a comprehensive JSON policy document that grants read-only access to a specific S3 bucket:\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Sid\": \"ListBucketContents\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:GetObjectVersion\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-bucket-name/*\"\n    },\n    {\n      \"Sid\": \"ListBucket\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:ListBucket\",\n        \"s3:GetBucketVersioning\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-bucket-name\"\n    }\n  ]\n}\n```\n\n## Policy Breakdown\n\n| Component | Purpose |\n|-----------|---------|\n| **Version** | Policy language version (always \"2012-10-17\") |\n| **Statement** | Array of permission rules |\n| **Sid** | Statement identifier (optional but recommended) |\n| **Effect** | \"Allow\" or \"Deny\" |\n| **Action** | S3 operations permitted |\n| **Resource** | AWS resources the policy applies to |\n\n## Key Permissions Explained\n\n- **s3:ListBucket** - View bucket contents\n- **s3:GetObject** - Download/read objects\n- **s3:GetObjectVersion** - Access object versions\n- **s3:GetBucketVersioning** - Check versioning status\n\n## Customization Guide\n\nReplace `my-bucket-name` with your actual bucket name:\n\n```json\n\"Resource\": \"arn:aws:s3:::your-actual-bucket-name/*\"\n```\n\n## Usage Example\n\nAttach this policy to an IAM user, role, or group to grant read-only S3 access:\n\n```bash\naws iam put-user-policy --user-name username \\\n  --policy-name s3-read-only \\\n  --policy-document file://policy.json\n```\n\nThis policy follows AWS best practices by providing minimal necessary permissions (principle of least privilege).",
#     "test_case": {
#       "task": "Create a JSON policy document that grants read-only access to a specific S3 bucket",
#       "format": "json"
#     },
#     "score": 7,
#     "reasoning": "The solution provides a solid foundation with correct AWS IAM policy syntax and good documentation. However, there is a structural issue: the first statement declares 'ListBucketContents' but lists object-level actions (GetObject, GetObjectVersion) without the bucket-level ListBucket action that would allow users to actually see what objects exist. While the second statement includes ListBucket, the policy organization and completeness could be improved. The solution also lacks discussion of additional permissions that are often required for practical read-only access and security best practices for limiting access scope."
#   },
#   {
#     "output": "# AWS IAM Role ARN Validation Regex\n\nHere's a comprehensive regex pattern to validate AWS IAM role ARNs:\n\n## Basic Pattern\n```regex\n^arn:aws:iam::\\d{12}:role/[\\w+=,.@-]+$\n```\n\n## More Strict Pattern (Recommended)\n```regex\n^arn:aws:iam::\\d{12}:role/[a-zA-Z0-9+=,.@_-]+$\n```\n\n## Most Comprehensive Pattern\n```regex\n^arn:aws:iam::\\d{12}:role/[a-zA-Z0-9!$&'()*+,.\\/:;=?@_-]+$\n```\n\n## Implementation Examples\n\n### Python\n```python\nimport re\n\npattern = r'^arn:aws:iam::\\d{12}:role/[\\w+=,.@-]+$'\n\ndef validate_iam_role_arn(arn):\n    return bool(re.match(pattern, arn))\n\n# Test cases\ntest_arns = [\n    \"arn:aws:iam::123456789012:role/MyRole\",\n    \"arn:aws:iam::123456789012:role/Service-Role\",\n    \"arn:aws:iam::123456789012:role/my-role-name\",\n    \"arn:aws:iam::123456789012:role/invalid arn\",  # Invalid (space)\n    \"arn:aws:iam::12345:role/MyRole\",  # Invalid (wrong account ID)\n]\n\nfor arn in test_arns:\n    print(f\"{arn}: {validate_iam_role_arn(arn)}\")\n```\n\n### JavaScript\n```javascript\nconst pattern = /^arn:aws:iam::\\d{12}:role\\/[\\w+=,.@-]+$/;\n\nfunction validateIAMRoleARN(arn) {\n    return pattern.test(arn);\n}\n\n// Test\nconsole.log(validateIAMRoleARN(\"arn:aws:iam::123456789012:role/MyRole\"));\n```\n\n## Pattern Breakdown\n\n| Component | Meaning |\n|-----------|---------|\n| `^` | Start of string |\n| `arn:aws:iam::` | Fixed ARN prefix |\n| `\\d{12}` | Exactly 12 digits (AWS Account ID) |\n| `:role/` | Role identifier |\n| `[\\w+=,.@-]+` | Role name (alphanumeric, underscore, plus, equals, comma, period, @, hyphen) |\n| `$` | End of string |\n\n## Key Features\n- \u2705 Validates 12-digit AWS account ID\n- \u2705 Ensures proper ARN format\n- \u2705 Allows AWS-compliant role name characters\n- \u2705 Prevents spaces and invalid characters\n- \u2705 Requires at least one character in role name\n\nChoose the pattern that best fits your use case!",
#     "test_case": {
#       "task": "Write a regex pattern to validate AWS IAM role ARNs (arn:aws:iam::account-id:role/role-name)",
#       "format": "regex"
#     },
#     "score": 6,
#     "reasoning": "The solution demonstrates good structure and practical implementation, but contains a significant accuracy issue in the 'Most Comprehensive Pattern' that contradicts AWS specifications. The patterns work for common cases but don't fully validate AWS IAM role naming rules and don't account for path-based roles. The missing reference to official AWS documentation is a notable gap for production use. While suitable for basic validation, the solution needs correction for strict compliance."
#   }
# ]
