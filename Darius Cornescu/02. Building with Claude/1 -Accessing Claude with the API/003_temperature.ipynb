# %%
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()
client = Anthropic()
model = "claude-sonnet-4-6"

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content":text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content":text}
    messages.append(assistant_message)

def chat(messages, system = None, temperature=1.0):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature
    }
    if system: params["system"] = system
    message = client.messages.create(**params)

    return message.content[0].text

# %%
messages = [] 
add_user_message(
    messages, 
    "Generate a joke for starting a comedy show")
answer = chat(messages, temperature=0.0)
print(answer)
# Out:
# Here's an opening joke:
#
# ---
#
# "Thank you all for coming out tonight! I asked my GPS how to get here and it said, *'In 500 feet, question all your life choices.'*
#
# So here I am. And apparently... so are you. 🎤"
#
# ---
#
# Short, relatable, and gets the crowd laughing *with* you right from the start! Want me to tailor it to a specific style or topic?

# %%
answer = chat(messages, temperature=1.0)
print(answer)
# Out:
# Here's an opener:
#
# ---
#
# **"I told my therapist I've been having trouble sleeping. She said, 'What's keeping you up at night?' I said, 'Honestly? The fear that I'm not as funny as I think I am.'**
#
# **...She didn't laugh. So now I have TWO problems."**
#
# ---
#
# 🎤 *Good energy, relatable, and sets up a self-aware tone perfect for warming up an audience!*
