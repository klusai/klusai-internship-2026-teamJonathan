# %%
from helpers import *

messages = []

add_user_message(messages, "Generate a one sentence movie idea")

answer=chat(messages,temperature=0.0)

answer
# Out:
# '# Movie Idea\n\nA cynical time-traveling insurance adjuster must prevent catastrophic accidents across history while falling in love with a rival adjuster from a competing timeline.'
