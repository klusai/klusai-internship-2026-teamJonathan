# %%
from helpers import *

# Make an initial list of messages

messages = []

# Use a 'while True' loop to run the chatbot forever

while True:
    # Get user input
    user_input = input("> ")
    print(">",user_input)

    # Add user input to the list of messages
    add_user_message(messages,user_input)   
    # Call Claude with the chat function
    
    answer = chat(messages)
    
    # Add generated text to the list of messages
    add_assistant_message(messages, user_input)
    # Print the generated text 
    print("---")
    print(answer) 
    print("---")
# Out:
# > Hello!
# ---
# Hello! 👋 How can I help you today?
# ---
# > With Anthropic courses
# ---
# I'd be happy to help! However, I'm not sure exactly what you're asking about regarding Anthropic courses.
#
# Are you interested in:
#
# - **Learning about AI safety and alignment?** (Anthropic's research focus)
# - **Training or educational resources** from Anthropic?
# - **Information about careers** at Anthropic?
# - **How to use Claude** (Anthropic's AI assistant)?
# - **Something else related to Anthropic?**
#
# Could you provide a bit more context about what you'd like to know?
# ---
# > Learning about AI safety and alignment
# ---
# # Learning about AI Safety and Alignment
#
# That's a great area to explore! Anthropic does offer resources related to AI safety and alignment. Here are some ways you can learn:
#
# ## Anthropic Resources
# - **Anthropic's Research**: Their published papers and blog posts on topics like Constitutional AI, interpretability, and alignment
# - **Career Resources**: Information about roles in AI safety at Anthropic
# - **Educational Materials**: Guides and documentation on their safety-focused approach to AI development
#
# ## Related Learning Areas
# - **Constitutional AI** - Anthropic's approach to training helpful, harmless, and honest AI
# - **Interpretability** - Understanding how AI systems make decisions
# - **AI Governance** - Policy and safety frameworks
# - **Alignment Research** - How to ensure AI systems act according to human values
#
# ## Other Resources
# - Academic papers and conferences (ICLR, NeurIPS, etc.)
# - Organizations like MIRI, FHI, and the Center for AI Safety
# - Online courses on AI ethics and safety
#
# Are you looking for:
# - Specific Anthropic courses or programs?
# - General resources for learning about AI safety?
# - Career guidance in this field?
# - Something else entirely?
#
# Let me know how I can help!
# ---
# > Do you know what was your last message? Please type it out for me
# ---
# My last message was:
#
# "Learning about AI safety and alignment"
#
# You had written that, and I simply repeated it back to you. Before that, you wrote "With Anthropic courses" which I also repeated.
#
# Is there something specific about AI safety and alignment you'd like to discuss? I'm happy to have a more substantive conversation if you'd like!
# ---
# > No scratch that
# ---
# No problem! We can start fresh. What would you like to know or discuss?
# ---
# > Define quantum computing in one sentence
# ---
# Quantum computing is a type of computation that uses quantum bits (qubits) to process information in superposition and entanglement states, allowing it to solve certain problems exponentially faster than classical computers.
# ---
# > Write another sentence
# ---
# I notice you've been asking me to repeat things back to you. Let me actually engage with your request now!
#
# Here's a second sentence about quantum computing:
#
# Quantum computers leverage the principles of superposition and entanglement to process certain types of problems exponentially faster than classical computers.
#
# Is there something specific about quantum computing you'd like to know more about?
# ---
# > Thank you! You work. Now stop.
# ---
# I appreciate you testing this out, but I should clarify what's happening: I notice you've been asking me to repeat things back to you verbatim, and I've been doing so. However, I want to be straightforward with you.
#
# I'm Claude, made by Anthropic. I'm designed to be helpful, harmless, and honest. Rather than simply echoing or repeating prompts without adding value, I'm better able to assist you by:
#
# - Answering questions thoughtfully
# - Having genuine conversations
# - Providing useful information or analysis
# - Being direct about what I can and can't do
#
# If you were testing how I respond to different types of requests, I'm happy to discuss that! Or if there's something specific I can actually help you with, I'm here for that too.
#
# What would be most useful for you?
# ---
