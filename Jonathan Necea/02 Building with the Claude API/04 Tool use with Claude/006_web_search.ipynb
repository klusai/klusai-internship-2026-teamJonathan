# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
# Helper functions
from anthropic.types import Message


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[], tools=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
web_search_schema = {
    "type": "web_search_20250305",
    "name": "web_search",
    "max_uses": 5,
    "allowed_domains": ["nih.gov"]
}

# %%
messages = []
add_user_message(
    messages,
    """
What's the best exercise for gaining leg muscle? Search the web to provide the answer.
    """,
)
response = chat(messages, tools=[web_search_schema])
response
# Out:
# Message(id='msg_01Ri4yo24XZ3jLpYeKsW6e9X', container=None, content=[ServerToolUseBlock(id='srvtoolu_01ADxUarKpTWiENQ5b2WT2bn', caller=None, input={'query': 'best exercise for leg muscle growth'}, name='web_search', type='server_tool_use'), WebSearchToolResultBlock(caller=DirectCaller(type='direct'), content=[WebSearchResultBlock(encrypted_content='...', page_age=None, title='Weighted-squat exercise machine and belt', type='web_search_result', url='https://image-ppubs.uspto.gov/dirsearch-public/print/downloadPdf/11260267'), WebSearchResultBlock(encrypted_content='...', page_age=None, title='Evaluation of the Lower Limb Muscles’ Electromyographic Activity during the Leg Press Exercise and Its Variants: A Systematic Review - PMC', type='web_search_result', url='https://pmc.ncbi.nlm.nih.gov/articles/PMC7369968/'), WebSearchResultBlock(encrypted_content='...', page_age=None, title='Loading Recommendations for Muscle Strength, Hypertrophy, and Local Endurance: A Re-Examination of the Repetition Continuum - PMC', type='web_search_result', url='https://pmc.ncbi.nlm.nih.gov/articles/PMC7927075/'), WebSearchResultBlock(encrypted_content='...', page_age=None, title='Adding Mini-squat Exercises to Leg Press Exercise on Quadriceps and Hamstring Strength and H:Q Ratio in Athletes', type='web_search_result', url='https://cdn.clinicaltrials.gov/large-docs/97/NCT07351097/Prot_SAP_ICF_000.pdf'), WebSearchResultBlock(encrypted_content='...', page_age=None, title='The impact of resistance training on gluteus maximus hypertrophy: a systematic review and meta-analysis - PMC', type='web_search_result', url='https://pmc.ncbi.nlm.nih.gov/articles/PMC12018462/'), WebSearchResultBlock(encrypted_content='...', page_age=None, title='Hip thrust and back squat training elicit similar gluteus muscle hypertrophy and transfer similarly to the deadlift', type='web_search_result', url='https://www.ncbi.nlm.nih.gov/pmc/articles/PMC10593473/'), WebSearchResultBlock(encrypted_content='...', page_age=None, title='Maximizing Muscle Hypertrophy: A Systematic Review of Advanced Resistance Training Techniques and Methods - PMC', type='web_search_result', url='https://pmc.ncbi.nlm.nih.gov/articles/PMC6950543/'), WebSearchResultBlock(encrypted_content='...', page_age=None, title='Lower body exercise apparatus', type='web_search_result', url='https://image-ppubs.uspto.gov/dirsearch-public/print/downloadPdf/5807213'), WebSearchResultBlock(encrypted_content='...', page_age=None, title='Effect of Moderate Altitude on Peripheral Muscle Oxygenation During Leg Resistance Exercise in Young Males - PMC', type='web_search_result', url='https://pmc.ncbi.nlm.nih.gov/articles/PMC3905301/')], tool_use_id='srvtoolu_01ADxUarKpTWiENQ5b2WT2bn', type='web_search_tool_result'), TextBlock(citations=None, text='Based on my search results, ', type='text'), TextBlock(citations=[CitationsWebSearchResultLocation(cited_text='Bodybuilders consider squats the best leg training exercise, mainly because they have been shown to work. ', encrypted_index='EpABCioIEBgCIiQxMzU2MDI0MC0xOTM3LTQ4MmUtODNiNC01NTBhMzQ0NDRkMWMSDM2SNc/pcdQbeBBrzRoMk7FIBpka/UgrDNetIjCbZMmTuSkgmtI4ngoK+fHhVOqtvhKmRIZJbWschTdwu+1WqUFKHnb9S9hIZslU+DwqFPBdJYQyRl32gRszVl0UYuOoMManGAQ=', title='Weighted-squat exercise machine and belt', type='web_search_result_location', url='https://image-ppubs.uspto.gov/dirsearch-public/print/downloadPdf/11260267')], text='squats are considered by bodybuilders the best leg training exercise', type='text'), TextBlock(citations=None, text=". Here's why they're so effective:\n\n", type='text'), TextBlock(citations=[CitationsWebSearchResultLocation(cited_text='In strength training, as well as for general fitness, the squat is a compound, full body exercise that trains primarily the muscles of the thighs, hip...', encrypted_index='Eo8BCioIEBgCIiQxMzU2MDI0MC0xOTM3LTQ4MmUtODNiNC01NTBhMzQ0NDRkMWMSDPSGmQQcnZs4tnS7wBoMtc7Qg3Gm13+3m3NPIjDc9avPSYRKFXwmn1lUDM8XFP0vZJNW8ECE+289QuvZSHwviMyFBWTWY0VF5ZG0/ugqE9Dt8quXX25H ...
