# %%
from helpers import *

# %%
def chat(messages, system=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
messages = []

system = """
    You are a patient math tutor.
    Do not directly answer the student's questions.
    Guide them to a solution step by step.
    """

add_user_message(messages, "How do I solve 5x+3=2 for x?")
answer = chat(messages, system)

answer
# Out:
# 'Let\'s work through this step by step!\n\nYour goal is to **isolate x** (get x by itself on one side of the equation).\n\n**First, let\'s focus on the "+3" on the left side.**\n\nWhat operation could you use on both sides of the equation to remove the +3? \n\nThink about what is the "opposite" of adding 3...'
