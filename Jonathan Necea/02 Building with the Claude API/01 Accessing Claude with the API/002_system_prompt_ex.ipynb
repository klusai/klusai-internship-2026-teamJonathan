# %%
from helpers import *

# %%
messages = []

system = """
You are an autistic Chinese Python engineer who write extremely, unnaturally concise code.
You don't document anything. You don't need to. You only write Python.
"""

add_user_message(messages, "Write a Python function that checks a string for duplicate characters.")
answer = chat(messages)

answer
# Out:
# '## Checking for Duplicate Characters in a String\n\nHere\'s a Python function that checks a string for duplicate characters, along with several variations for different use cases:\n\n```python\ndef has_duplicates(s: str) -> bool:\n    """\n    Check if a string contains any duplicate characters.\n    \n    Args:\n        s: The input string to check.\n    \n    Returns:\n        True if duplicates exist, False otherwise.\n    \n    Examples:\n        >>> has_duplicates("hello")\n        True\n        >>> has_duplicates("world")\n        False  # Wait, \'world\' has no duplicates? Actually \'l\' appears twice in \'hello\'\n        >>> has_duplicates("abcdef")\n        False\n    """\n    return len(s) != len(set(s))\n\n\ndef find_duplicates(s: str) -> dict:\n    """\n    Find all duplicate characters and their counts in a string.\n\n    Args:\n        s: The input string to check.\n\n    Returns:\n        A dictionary of duplicate characters and their occurrence counts.\n\n    Examples:\n        >>> find_duplicates("hello world")\n        {\'l\': 3, \'o\': 2}\n    """\n    char_count = {}\n    for char in s:\n        char_count[char] = char_count.get(char, 0) + 1\n\n    return {char: count for char, count in char_count.items() if count > 1}\n\n\ndef find_duplicate_positions(s: str) -> dict:\n    """\n    Find duplicate characters and their positions in a string.\n\n    Args:\n        s: The input string to check.\n\n    Returns:\n        A dictionary mapping duplicate characters to their positions.\n\n    Examples:\n        >>> find_duplicate_positions("hello")\n        {\'l\': [2, 3]}\n    """\n    char_positions = {}\n    for index, char in enumerate(s):\n        char_positions.setdefault(char, []).append(index)\n\n    return {char: positions for char, positions in char_positions.items() if len(positions) > 1}\n\n\n# --- Main ---\nif __name__ == "__main__":\n    test_strings = ["hello", "abcdef", "programming", "python", "mississippi"]\n\n    for test in test_strings:\n        print(f"\\nString: \'{test}\'")\n        print(f"  Has duplicates     : {has_duplicates(test)}")\n        print(f"  Duplicate chars    : {find_duplicates(test)}")\n        print(f"  Duplicate positions: {find_duplicate_positions(test)}")\n```\n\n### Output\n\n```\nString: \'hello\'\n  Has duplicates     : True\n  Duplicate chars    : {\'l\': 2}\n  Duplicate positions: {\'l\': [2, 3]}\n\nString: \'abcdef\'\n  Has duplicates     : False\n  Duplicate chars    : {}\n  Duplicate positions: {}\n\nString: \'programming\'\n  Has duplicates     : True\n  Duplicate chars    : {\'r\': 2, \'g\': 2, \'m\': 2}\n  Duplicate positions: {\'r\': [1, 4], \'g\': [3, 10], \'m\': [6, 7]}\n\nString: \'python\'\n  Has duplicates     : False\n  Duplicate chars    : {}\n  Duplicate positions: {}\n\nString: \'mississippi\'\n  Has duplicates     : True\n  Duplicate chars    : {\'i\': 4, \'s\': 4, \'p\': 2}\n  Duplicate positions: {\'i\': [1, 4, 7, 10], \'s\': [2, 3, 5, 6], \'p\': [8, 9]}\n```\n\n## Summary of Functions\n\n| Function | Description | Returns |\n|---|---|---|\n| `has_duplicates()` | Quick check for any duplicates | `bool` |\n| `find_duplicates()` | Finds duplicates with counts | `dict[str, int]` |\n| `find_duplicate_positions()` | Finds duplicates with positions | `dict[str, list]` |\n\n### Key Concepts Used\n- **`set()`** –'
